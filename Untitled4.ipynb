# %%
print('shubham')
# Out:
# shubham

# %%
'''hjf
ff
fff
fff
ff
f
ff'''
# Out:
# 'hjf\nff\nfff\nfff\nff\nf\nff'

# %%
#My name is shubham chavan and i am a fresher

# %%
#print("hbddjnd")
print("hfjfhf")
# Out:
# hfjfhf

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a,b,c = 10 , "shubham", "bhshjj"

# %%
a
# Out:
# 10

# %%
b
# Out:
# 'shubham'

# %%
c
# Out:
# 'bhshjj'

# %%
type(a)
# Out:
# int

# %%
type (b)
# Out:
# str

# %%
print(a)
# Out:
# 10

# %%
a
# Out:
# 10

# %%
b
# Out:
# 'shubham'

# %%
print(a,b,c)
# Out:
# 10 shubham bhshjj

# %%
b
# Out:
# 'shubham'

# %%
_b = "hjed"

# %%
a=1.6

# %%
type(a)
# Out:
# float

# %%
b = True
c = False

# %%
 type(a)
# Out:
# float

# %%
type(b)
# Out:
# bool

# %%
print(True + True +True + False+ True)

print(False - True+True )
# Out:
# 4
# 0

# %%
n=45+6j

# %%
type(n)
# Out:
# complex

# %%
n.real
# Out:
# 45.0

# %%
n.imag
# Out:
# 6.0

# %%
"1"+ "shubh"
# Out:
# '1shubh'

# %%
1+0.55
# Out:
# 1.55

# %%
"shubh" * 3
# Out:
# 'shubhshubhshubh'

# %%
"shubh" * "shubh"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-6341ded63bf0> in <module>
# ----> 1 "shubh" * "shubh"
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
a =input()
# Out:
# bdbdsbcscdc

# %%
a
# Out:
# 'bdbdsbcscdc'

# %%
a=input()
# Out:
# jfifjfjf

# %%
b=input()
# Out:
# nfjfns

# %%
c=input()
# Out:
# mkmvf

# %%
a+b/c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-6ced12e58eca> in <module>
# ----> 1 a+b/c
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
a=10

# %%
a
# Out:
# 10

# %%
a=input()
# Out:
# 10

# %%
b=input()

# %%
c+
