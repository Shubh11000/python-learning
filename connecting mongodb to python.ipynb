# %%
import pymongo
dbConn = pymongo.MongoClient("mongodb://localhost:27017/")
db = dbConn[dbname]

# %%
collection_name="combine"

collection=db[collection_name]

# %%
result= collection.find({})

# %%
data=list(result)

# %%
len(data)
# Out:
# 919879

# %%
pd.DataFrame(data)
# Out:
#                              _id                          company  \
# 0       6256c4b567ee11064d17ecbf                 A C M Industries
# 1       6256c4b567ee11064d17ed7b                R S Communication
# 2       6256c4b567ee11064d17efd8                     R S Agencies
# 3       6256c4b567ee11064d17f2e0           A A Plastic Industries
# 4       6256c4b567ee11064d17f37b                B  Sons Tailoring
# ...                          ...                              ...
# 919874  6274ee6b14d1a5f667e637ac  Larsen  &  Toubro Infotech Ltd
# 919875  6274ee6b14d1a5f667e63cdf    H M T (International) Limited
# 919876  6274ee6c14d1a5f667e67521                Government of Goa
# 919877  6274ee7614d1a5f667e74c9a      Oracle Auto Private Limited
# 919878  6274ee7614d1a5f667e74ca4             Kotak Mahindra Bank
#
#                Mobile                                         experience  \
# 0          9414272274  [{"company":{"name":"keane","size":"5001-10000...
# ...
